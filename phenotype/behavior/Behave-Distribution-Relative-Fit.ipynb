# %%
import pandas as pd
from pandas import DataFrame
from sklearn.utils import resample

flag=[]
russ=[]
peck=[]
synu=[]
cran=[]
bifr=[]


data2=pd.read_csv("/Users/revbayes/Desktop/McLean/Manuscripts/In_Preparation/Edwards_Aquifer/Light_Response/Round_11/supplimental_materials/data_code/phenotype/behavior/BehaveData.csv")

flag1=data2["flagellatus"]
flag += flag1.tolist()
flag2=flag[0:5]
flag_boot = resample(flag2, replace=True, n_samples=500, random_state=1)

russ1=data2["russelli"]
russ += russ1.tolist()
russ2=russ[0:10]
russ_boot = resample(russ2, replace=True, n_samples=500, random_state=1)

peck1=data2["pecki"]
peck += peck1.tolist()
peck2=peck[0:5]
peck_boot = resample(peck2, replace=True, n_samples=100, random_state=1)

synu1=data2["Sicifera"]
synu += synu1.tolist()
synu2=synu[0:10]
synu_boot = resample(synu2, replace=True, n_samples=500, random_state=1)

cran1=data2["Crangonyx "]
cran += cran1.tolist()
cran2=cran[0:5]
cran_boot = resample(cran2, replace=True, n_samples=500, random_state=1)

bifr1=data2["bifurcatus"]
bifr += bifr1.tolist()
bifr2=bifr[0:5]
bifr_boot = resample(bifr2, replace=True, n_samples=500, random_state=1)

print(peck2)
# Out:
# [0.866666667, 0.733333333, 0.933333333, 0.6, 0.933333333]

# %%
import statistics
import seaborn as sns
import numpy as np
import scipy.stats as stats
from scipy.stats import beta
import matplotlib.pyplot as plt
import matplotlib as mpl



neutral = beta.rvs(9, 9, size=1000 )
photophilic = beta.rvs(1,5, size=1000)
photophobic = beta.rvs(5,1, size=1000)

plt.figure(figsize=(12,8))

plt.plot([0.5, 0.5], [0.0, 4], 'k-', color='red', linewidth=3)
plt.plot([0.17, 0.17], [0.0, 4], 'k-', color='red', linewidth=3)
plt.plot([0.83, 0.83], [0.0, 4], 'k-', color='red', linewidth=3)



sns.kdeplot(np.array(neutral), bw=.7, label="photoneutral", color='black', linewidth=5)
sns.kdeplot(np.array(photophilic), bw=.7, label="photophilic", color='black', linestyle='dashed', linewidth=5)
sns.kdeplot(np.array(photophobic), bw=.7, label="photophobic", color='black', linestyle='dotted', linewidth=5)
plt.yticks([])
plt.xlabel('Proportion of time avoiding direct light')
plt.ylabel('Probability density')
_ = plt.legend()

plt.xlim(xmin=0)
plt.xlim(xmax=1)
plt.ylim(ymax=4)  

#print(neutral)

print(statistics.mean(photophilic))
print(statistics.mean(photophobic))

mpl.rcParams.update({'font.size': 20})
# Out:
# /var/folders/7b/8ks4cl_14bl9b9cq4rzpvynw0000gp/T/ipykernel_44429/2347589818.py:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0.5, 0.5], [0.0, 4], 'k-', color='red', linewidth=3)
# /var/folders/7b/8ks4cl_14bl9b9cq4rzpvynw0000gp/T/ipykernel_44429/2347589818.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0.17, 0.17], [0.0, 4], 'k-', color='red', linewidth=3)
# /var/folders/7b/8ks4cl_14bl9b9cq4rzpvynw0000gp/T/ipykernel_44429/2347589818.py:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0.83, 0.83], [0.0, 4], 'k-', color='red', linewidth=3)
# ...

# %%
plt.figure(figsize=(20,12))

plt.plot([0.5, 0.5], [0.0, 5], 'k-', color='black', linewidth=5)

sns.kdeplot(np.array(neutral), bw=.75, label="photoneutral", color='black', linewidth=5)
sns.kdeplot(np.array(photophilic), bw=.75, label="photophilic", color='black', linestyle='dashed', linewidth=5)
sns.kdeplot(np.array(photophobic), bw=.75, label="photophobic", color='black', linestyle='dotted', linewidth=5)

sns.kdeplot(np.array(cran_boot), bw=.75, label="Crangonyx sp.", color='orange', linestyle='dashed',  linewidth=5)
#sns.kdeplot(np.array(cran2), bw=.09, label="cran_raw", color='purple', linestyle='dashed')

sns.kdeplot(np.array(bifr_boot), bw=.75, label="S. bifurcatus", color='green', linestyle='dashed', linewidth=5)
#sns.kdeplot(np.array(bifr2), bw=.09, label="bifr_raw", color='purple', linestyle='dashed')

sns.kdeplot(np.array(flag_boot), bw=1.25, label="S. flagellatus", color='green',  linewidth=5)
#sns.kdeplot(np.array(flag2), bw=.09, label="flag_raw", color='green', linestyle='dashed')

sns.kdeplot(np.array(peck_boot), bw=.75, label="S. pecki", color='red',  linewidth=5)
#sns.kdeplot(np.array(peck2), bw=.09, label="peck_raw", color='red', linestyle='dashed')

sns.kdeplot(np.array(russ_boot), bw=.75, label="S. russelli", color='orange',  linewidth=5)
#sns.kdeplot(np.array(russ2), bw=.09, label="russ_raw", color='orange', linestyle='dashed')

sns.kdeplot(np.array(synu_boot), bw=.75, label="Sicifera sp.", color='yellow',  linewidth=5)
#sns.kdeplot(np.array(synu2), bw=.09, label="synu_raw", color='yellow', linestyle='dashed')


#print(flag_boot)

plt.yticks([])
plt.xlim(xmin=0)
plt.xlim(xmax=1)
plt.ylim(ymax=5)
plt.ylabel('Probability density')

_ = plt.legend()

plt.xlabel('Proportion of time avoiding direct light')


mpl.rcParams.update({'font.size': 20})
# Out:
# /var/folders/7b/8ks4cl_14bl9b9cq4rzpvynw0000gp/T/ipykernel_73991/1206734116.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0.5, 0.5], [0.0, 5], 'k-', color='black', linewidth=5)
# /Users/revbayes/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.75 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /Users/revbayes/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.75 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
def beta_binom(prior, y):
    """
    Compute the marginal likelihood, analytically, for a beta-binomial model.

    prior : tuple
        tuple of alpha and beta parameter for the prior (beta distribution)
    y : array
        array with "1" and "0" corresponding to the success and fails respectively
    """
    alpha, beta = prior
    h = np.sum(y)
    n = len(y)
    p_y = np.exp(betaln(alpha + h, beta+n-h) - betaln(alpha, beta))
    return p_y

# %%
plt.figure(figsize=(12,8))

priors = ((2, 8), (9, 9), (8,2), (1,1))
for a, b in priors:
    distri = beta(a, b)
    x = np.linspace(0, 1, 100)
    x_pdf = distri.pdf(x)
    plt.plot (x, x_pdf, label=r'$\alpha$ = {:d}, $\beta$ = {:d}'.format(a, b))
    plt.yticks([])
    plt.xlabel('$\\theta$')
    plt.legend()

# %% [markdown]
# The following compares the shape of the priors to the simulated data. In this case I only ran it for Stygobromus bifurcatus but it can be ran for all species simply by redefining "y = ....."

# %%
import scipy as sp
neutral_model = sp.stats.beta(5,5)
neutral_model.pdf(0.5)
# Out:
# 2.460937500000001

# %%
#pecki

neutral_model = sp.stats.beta(9,9)
philic_model = sp.stats.beta(2,8)
phobic_model = sp.stats.beta(8,2)
#neutral_model.pdf(1)

kde_for_one_species = stats.gaussian_kde(peck2)
total_for_philic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = philic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_philic += x

kde_for_one_species = stats.gaussian_kde(peck2)
total_for_neutral = 0
for i in np.arange(-0.2,1.2,0.005):
    model = neutral_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_neutral += x

kde_for_one_species = stats.gaussian_kde(peck2)
total_for_phobic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = phobic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_phobic += x

total_for_philic=total_for_philic/200
total_for_neutral=total_for_neutral/200
total_for_phobic=total_for_phobic/200
    
print(total_for_philic)
print(total_for_neutral)
print(total_for_phobic)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.05229657]
# [0.28290368]
# [0.7824207]

# %%
#flagelattus 

neutral_model = sp.stats.beta(9,9)
philic_model = sp.stats.beta(2,8)
phobic_model = sp.stats.beta(8,2)
#neutral_model.pdf(1)

kde_for_one_species = stats.gaussian_kde(flag2)
total_for_philic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = philic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_philic += x

kde_for_one_species = stats.gaussian_kde(flag2)
total_for_neutral = 0
for i in np.arange(-0.2,1.2,0.005):
    model = neutral_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_neutral += x

kde_for_one_species = stats.gaussian_kde(flag2)
total_for_phobic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = phobic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_phobic += x

total_for_philic=total_for_philic/200
total_for_neutral=total_for_neutral/200
total_for_phobic=total_for_phobic/200
    
print(total_for_philic)
print(total_for_neutral)
print(total_for_phobic)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.09001595]
# [0.71122267]
# [0.14196153]

# %%
#bifurcatus

neutral_model = sp.stats.beta(9,9)
philic_model = sp.stats.beta(2,8)
phobic_model = sp.stats.beta(8,2)
#neutral_model.pdf(1)

kde_for_one_species = stats.gaussian_kde(bifr2)
total_for_philic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = philic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_philic += x

kde_for_one_species = stats.gaussian_kde(bifr2)
total_for_neutral = 0
for i in np.arange(-0.2,1.2,0.005):
    model = neutral_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_neutral += x

kde_for_one_species = stats.gaussian_kde(bifr2)
total_for_phobic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = phobic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_phobic += x

total_for_philic=total_for_philic/200
total_for_neutral=total_for_neutral/200
total_for_phobic=total_for_phobic/200
    
print(total_for_philic)
print(total_for_neutral)
print(total_for_phobic)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.29094719]
# [0.73841853]
# [0.09971299]

# %%
#russelli

neutral_model = sp.stats.beta(9,9)
philic_model = sp.stats.beta(2,8)
phobic_model = sp.stats.beta(8,2)
#neutral_model.pdf(1)

kde_for_one_species = stats.gaussian_kde(russ2)
total_for_philic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = philic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_philic += x

kde_for_one_species = stats.gaussian_kde(russ2)
total_for_neutral = 0
for i in np.arange(-0.2,1.2,0.005):
    model = neutral_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_neutral += x

kde_for_one_species = stats.gaussian_kde(russ2)
total_for_phobic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = phobic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_phobic += x

total_for_philic=total_for_philic/200
total_for_neutral=total_for_neutral/200
total_for_phobic=total_for_phobic/200
    
print(total_for_philic)
print(total_for_neutral)
print(total_for_phobic)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.04247288]
# [0.29941944]
# [0.71248848]

# %%
#Synurella

neutral_model = sp.stats.beta(9,9)
philic_model = sp.stats.beta(2,8)
phobic_model = sp.stats.beta(8,2)
#neutral_model.pdf(1)

kde_for_one_species = stats.gaussian_kde(synu2)
total_for_philic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = philic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_philic += x

kde_for_one_species = stats.gaussian_kde(synu2)
total_for_neutral = 0
for i in np.arange(-0.2,1.2,0.005):
    model = neutral_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_neutral += x

kde_for_one_species = stats.gaussian_kde(synu2)
total_for_phobic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = phobic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_phobic += x

total_for_philic=total_for_philic/200
total_for_neutral=total_for_neutral/200
total_for_phobic=total_for_phobic/200
    
print(total_for_philic)
print(total_for_neutral)
print(total_for_phobic)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.17504971]
# [0.57999147]
# [0.56088712]

# %%
#Crangronyx

neutral_model = sp.stats.beta(9,9)
philic_model = sp.stats.beta(2,8)
phobic_model = sp.stats.beta(8,2)
#neutral_model.pdf(1)

kde_for_one_species = stats.gaussian_kde(cran2)
total_for_philic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = philic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_philic += x

kde_for_one_species = stats.gaussian_kde(cran2)
total_for_neutral = 0
for i in np.arange(-0.2,1.2,0.005):
    model = neutral_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_neutral += x

kde_for_one_species = stats.gaussian_kde(cran2)
total_for_phobic = 0
for i in np.arange(-0.2,1.2,0.005):
    model = phobic_model.pdf(i)
    data = kde_for_one_species.pdf(i)
    x= min(model,data)
    total_for_phobic += x

total_for_philic=total_for_philic/200
total_for_neutral=total_for_neutral/200
total_for_phobic=total_for_phobic/200
    
print(total_for_philic)
print(total_for_neutral)
print(total_for_phobic)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.06861563]
# [0.44612667]
# [0.67828116]

# %%
#species comparisons 

kde_for_one_species1 = stats.gaussian_kde(cran2)
kde_for_one_species2 = stats.gaussian_kde(synu2)
total_for_comp1 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp1 += x

total_for_comp1=total_for_comp1/200
    
kde_for_one_species1 = stats.gaussian_kde(cran2)
kde_for_one_species2 = stats.gaussian_kde(bifr2)
total_for_comp2 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp2 += x
    
total_for_comp2=total_for_comp2/200

kde_for_one_species1 = stats.gaussian_kde(cran2)
kde_for_one_species2 = stats.gaussian_kde(flag2)
total_for_comp3 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp3 += x
    
total_for_comp3=total_for_comp3/200

kde_for_one_species1 = stats.gaussian_kde(cran2)
kde_for_one_species2 = stats.gaussian_kde(peck2)
total_for_comp4 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp4 += x
    
total_for_comp4=total_for_comp4/200

kde_for_one_species1 = stats.gaussian_kde(cran2)
kde_for_one_species2 = stats.gaussian_kde(russ2)
total_for_comp5 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp5 += x
    
total_for_comp5=total_for_comp5/200

kde_for_one_species1 = stats.gaussian_kde(synu2)
kde_for_one_species2 = stats.gaussian_kde(bifr2)
total_for_comp6 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp6 += x
    
total_for_comp6=total_for_comp6/200

kde_for_one_species1 = stats.gaussian_kde(synu2)
kde_for_one_species2 = stats.gaussian_kde(flag2)
total_for_comp7 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp7 += x
    
total_for_comp7=total_for_comp7/200

kde_for_one_species1 = stats.gaussian_kde(synu2)
kde_for_one_species2 = stats.gaussian_kde(peck2)
total_for_comp8 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp8 += x
    
total_for_comp8=total_for_comp8/200

kde_for_one_species1 = stats.gaussian_kde(synu2)
kde_for_one_species2 = stats.gaussian_kde(russ2)
total_for_comp9 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp9 += x
    
total_for_comp9=total_for_comp9/200

kde_for_one_species1 = stats.gaussian_kde(bifr2)
kde_for_one_species2 = stats.gaussian_kde(flag2)
total_for_comp10 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp10 += x
    
total_for_comp10=total_for_comp10/200

kde_for_one_species1 = stats.gaussian_kde(bifr2)
kde_for_one_species2 = stats.gaussian_kde(peck2)
total_for_comp11 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp11 += x
    
total_for_comp11=total_for_comp11/200

kde_for_one_species1 = stats.gaussian_kde(bifr2)
kde_for_one_species2 = stats.gaussian_kde(russ2)
total_for_comp12 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp12 += x
    
total_for_comp12=total_for_comp12/200

kde_for_one_species1 = stats.gaussian_kde(flag2)
kde_for_one_species2 = stats.gaussian_kde(peck2)
total_for_comp13 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp13 += x
    
total_for_comp13=total_for_comp13/200

kde_for_one_species1 = stats.gaussian_kde(flag2)
kde_for_one_species2 = stats.gaussian_kde(russ2)
total_for_comp14 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp14 += x
    
total_for_comp14=total_for_comp14/200

kde_for_one_species1 = stats.gaussian_kde(peck2)
kde_for_one_species2 = stats.gaussian_kde(russ2)
total_for_comp15 = 0
for i in np.arange(-0.2,1.2,0.005):
    species1 = kde_for_one_species1.pdf(i)
    species2 = kde_for_one_species2.pdf(i)
    x= min(species1, species2)
    total_for_comp15 += x
    
total_for_comp15=total_for_comp15/200



print(total_for_comp1)
print(total_for_comp2)
print(total_for_comp3)
print(total_for_comp4)
print(total_for_comp5)
print('break')
print(total_for_comp6)
print(total_for_comp7)
print(total_for_comp8)
print(total_for_comp9)
print('break')
print(total_for_comp10)
print(total_for_comp11)
print(total_for_comp12)
print('break')
print(total_for_comp13)
print(total_for_comp14)
print('break')
print(total_for_comp15)

#think of this as a score and not a probabilty
# ~200 is the max overlap. Divide by 200 to normalize to proportion
# Out:
# [0.78261023]
# [0.24635691]
# [0.35979109]
# [0.73353209]
# [0.76739439]
# break
# [0.4129802]
# [0.4136318]
# [0.68733388]
# [0.71249437]
# break
# [0.57531859]
# [0.1493926]
# [0.1421908]
# break
# [0.20409458]
# [0.21516436]
# break
# [0.89817193]
